# %% [markdown]
# # a280

# %%
run algorithms/tsp/main.py -benchmark a280 -population_size 35 -generations_num 2000 -mutation_chance 0.3 -mutation_window 70 -crossover_chance 0.35 -crossover_window 30
# Out:
# No handles with labels found to put in legend.
# Best result by Genetic Algorithm: 11668.393629684619
# Total time: 63.76700040000014
# Route: [ 76  81  73 120 268 220 202 189 217 139 149 176 161  86 113  77  94  98
#   95  92 109 171 151 154 143 205 259 274  17 135 127 155 117  71  68  52
#   38  47  36  32  53  30 136 183 152  82  88 167 168 100  72  97 166 142
#  153 131  23  15   8   1  11  13  12   7   9   2 244 245 241 232 277   6
#  276 280 254   5  10  25 265 253 148 179 191 197 150 267 138 269 140 141
#  279 208 243 240 250 223 225 209 257 261 275  14 271 272  26  20 124 133
#   22  21  16 263 262 273 247 252 201 146 184 158 214 239 213 222 218 221
#  211 207 249 226 236 230 258 260 246 238 237 233 229   4 212 224 219 234
#  235 185 182 164 104  70  66  59  64  58  56  41  34 129 156 180 203 204
#  216 251 132 125 122 121 181 195 187 165  91  61  62 106 186 110  93  79
#  102 173 170 107  89  85  67  74  78  57 111 118  87 116  60  49  48  29
# ...

# %% [markdown]
# # ch150

# %%
run algorithms/tsp/main.py -benchmark ch150 -population_size 40 -generations_num 1500 -mutation_chance 0.3 -mutation_window 70 -crossover_chance 0.3 -crossover_window 50
# Out:
# No handles with labels found to put in legend.
# Best result by Genetic Algorithm: 17648.61563269334
# Total time: 29.79654969999956
# Route: [  6  12  53  24  49  36  69 127  20  25  70  29 139  40  28  42  37 120
#   61  60 130 140 117  27 106  13 136  72 144  14   4  45  31 129 112  71
#  115 150  68 128  44 104  22  10 113 121  15  78  80 125  62  48   3   7
#   89 124  97 143 107   5   1  95  82  87  88  30 103  34  76  73  98  84
#    8 142  18  75 141  58  55  81 108 102  99  50  86  65  83  43 138  93
#   96 133 131  67 109 134  52  35  94  63  33 149  64  23 126 105  77  74
#   91 119 123 145 147  57 101  39  41  17 148  66  11 118  47  51  90  54
#   26 146  56  85 135   2   9 114  19 110 116  46  92 100 137 132  59  79
#   21 111  16  32  38 122]

# %% [markdown]
# # fl417

# %%
run algorithms/tsp/main.py -benchmark fl417 -population_size 40 -generations_num 2000 -mutation_chance 0.25 -mutation_window 100 -crossover_chance 0.4 -crossover_window 45
# Out:
# No handles with labels found to put in legend.
# Best result by Genetic Algorithm: 126700.41046011595
# Total time: 136.28261170000042
# Route: [378 225  29  10 324 334  49  92  66  96 105 360 405 382 391 237 240 278
#  285 380 402 184 193 335 337 185 189 192 135 303  37 102 247 209 392 362
#  358 381 361 359 403 366 368 229 390  94  84  57 198 169 164 165 154 353
#   39  80  76  97  67  93 367 220 313 158 182  18  53  56  17 147 336 191
#  175 177 170 315  16 119 305 348 115 308 307  27 351 355 326  15  14   6
#  172 349 166 188   4  11 354  19 233 206 205 227 365 364  91  78 253 251
#  376 226 241 246 300 302 149 112 138 114 109 210 222 218 234 249 283 292
#  295 269 375 394 384  95  65 103 212 393 221 215 244  79  83 272 258  68
#   98 413 287 273 282 395 106 150 343 161 168  46  47  26 196 181 178 155
#  173 199 167 162 179  30  33  90 370 243 216 204 286 379  64  87 242 219
#  238 208 211 202 239 256 288 297 261 275 264 268 254 263 260 276 293 262
# ...

# %% [markdown]
# # att48
# mutation_window 70 means full inversion

# %%
run algorithms/tsp/main.py -benchmark att48 -population_size 35 -generations_num 2000 -mutation_chance 0.3 -mutation_window 70 -crossover_chance 0.35 -crossover_window 30
# Out:
# No handles with labels found to put in legend.
# Best result by Genetic Algorithm: 11821.0
# Total time: 11.6393603000015
# Route: [ 8  1 16 22  3 34 41 29 48 39  5  2 42 26  4 35 45 10 24 32 21 13 25 14
#  11 23 47 12 15 40  9 38 31 44  7 18 36 30 43 17 27  6 37 19 28 46 33 20]

# %% [markdown]
# # bays29

# %%
run algorithms/tsp/main.py -benchmark bays29 -population_size 20 -generations_num 2000 -mutation_chance 0.1 -mutation_window 9 -crossover_chance 0.1 -crossover_window 4
# Out:
# No handles with labels found to put in legend.
# Best result by Genetic Algorithm: 2097.0
# Total time: 3.579274499999883
# Route: [ 7 25 14 18 17 22 11 19 15  4 20 10 13 24 21  5  2  3 29 26  9 12  6 28
#   1  8 27 16 23]

# %% [markdown]
# # gr17

# %%
run algorithms/tsp/main.py -benchmark bays29 -population_size 6 -generations_num 1100 -mutation_chance 0.09 -mutation_window 100 -crossover_chance 0.1 -crossover_window 5
# Out:
# No handles with labels found to put in legend.
# Best result by Genetic Algorithm: 2524.0
# Total time: 0.6032886000011786
# Route: [18 17 22 14  4 10 20  5  3 29 26  2 28 21  9 12  6  1 23  8 24 13 27 16
#  11 15 19 25  7]
